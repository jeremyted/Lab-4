# %% [markdown]
# # Lab 4

# %% [markdown]
# # Introduction

# %% [markdown]
# This lab goes through a variety of methods of cleaning data, starting with the exploration of datasets to see what types of adjustments may be needed to make a file readable and usable.
# The main theme you will probably draw from this is just how complex and thoughtful data cleaning can be. It takes some work but it pays off and it is nice to organize data in a comprehensive manner

# %% [markdown]
# # Dataset Exploration

# %% [markdown]
# I want to start by importing useful functions to apply to the messy data we'll deal with.

# %%
# I'm creating function shortcuts here

import math as m
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Then, I'm going to open up my files and read them onto my notebook here

df_a = pd.read_excel('attendance.xls', encoding = "iso-8859-1")
df_s = pd.read_csv('sales.csv', encoding = "iso-8859-1")

# %%
# Here are the columns because 123 entries is too much
list(df_b)
# Out:
# ['Timestamp',
#  'Are you going trick or treating?',
#  'Your gender:',
#  'How old are you?',
#  'Which country do you live in?',
#  'Which state, province, county do you live in?',
#  ' [100 Grand Bar]',
#  ' [Anonymous brown globs that come in black and orange wrappers]',
#  ' [Any full-sized candy bar]',
#  ' [Black Jacks]',
#  ' [Bonkers (the candy)]',
#  ' [Bonkers (the board game)]',
#  ' [Bottle Caps]',
#  " [Box'o'Raisins]",
#  ' [Broken glow stick]',
#  ' [Butterfinger]',
#  ' [Cadbury Creme Eggs]',
#  ' [Candy Corn]',
#  ' [Candy that is clearly just the stuff given out for free at restaurants]',
#  ' [Caramellos]',
#  ' [Cash, or other forms of legal tender]',
#  ' [Chardonnay]',
#  ' [Chick-o-Sticks (we don’t know what that is)]',
#  ' [Chiclets]',
#  ' [Coffee Crisp]',
#  ' [Creepy Religious comics/Chick Tracts]',
#  ' [Dental paraphenalia]',
#  ' [Dots]',
#  ' [Dove Bars]',
#  ' [Fuzzy Peaches]',
#  ' [Generic Brand Acetaminophen]',
#  ' [Glow sticks]',
# ...

# %% [markdown]
# Now I want to see the basic information in each of the different datasets

# %% [markdown]
# #### Exploring the Boing Boing candy set data

# %%
df_b = pd.read_excel('BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx', encoding = "iso-8859-1"

# %%
# Here is the boing boing data info
df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Columns: 123 entries, Timestamp to  [York Peppermint Patties] Ignore
# dtypes: datetime64[ns](1), float64(1), object(121)
# memory usage: 1.2+ MB

# %%
# Here are the columns because 123 entries is too much
list(df_b)
# Out:
# ['Timestamp',
#  'Are you going actually going trick or treating yourself?',
#  'Your gender:',
#  'How old are you?',
#  'Which country do you live in?',
#  'Which state, province, county do you live in?',
#  ' [100 Grand Bar]',
#  ' [Anonymous brown globs that come in black and orange wrappers]',
#  ' [Any full-sized candy bar]',
#  ' [Black Jacks]',
#  ' [Bonkers (the candy)]',
#  ' [Bonkers (the board game)]',
#  ' [Bottle Caps]',
#  " [Box'o'Raisins]",
#  ' [Broken glow stick]',
#  ' [Butterfinger]',
#  ' [Cadbury Creme Eggs]',
#  ' [Candy Corn]',
#  ' [Candy that is clearly just the stuff given out for free at restaurants]',
#  ' [Caramellos]',
#  ' [Cash, or other forms of legal tender]',
#  ' [Chardonnay]',
#  ' [Chick-o-Sticks (we don’t know what that is)]',
#  ' [Chiclets]',
#  ' [Coffee Crisp]',
#  ' [Creepy Religious comics/Chick Tracts]',
#  ' [Dental paraphenalia]',
#  ' [Dots]',
#  ' [Dove Bars]',
#  ' [Fuzzy Peaches]',
#  ' [Generic Brand Acetaminophen]',
# ...

# %%
# I'm going to take a look at the first five rows to see what type of reponses were submitted
df_b.head(2)
# Out:
#                 Timestamp  \
# 0 2016-10-24 05:09:23.033
# 1 2016-10-24 05:09:54.798
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
#
#   Which state, province, county do you live in?  [100 Grand Bar]  \
# 0                                       Ontario              JOY
# 1                                            il              MEH
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# 1                                                MEH
#
#    [Any full-sized candy bar]  [Black Jacks]  ...  \
# 0                         JOY            MEH  ...
# ...

# %%
# Here. I'm just curious to see what the black jacks entries look like
df_b.groupby(' [Black Jacks]').count()
# Out:
#                 Timestamp  \
#  [Black Jacks]
# DESPAIR               513
# JOY                    76
# MEH                   467
#
#                 Are you going actually going trick or treating yourself?  \
#  [Black Jacks]
# DESPAIR                                                       513
# JOY                                                            76
# MEH                                                           467
#
#                 Your gender:  How old are you?  Which country do you live in?  \
#  [Black Jacks]
# DESPAIR                  508               498                            504
# JOY                       76                74                             75
# MEH                      465               457                            461
#
#                 Which state, province, county do you live in?  \
#  [Black Jacks]
# DESPAIR                                                   490
# JOY                                                        72
# ...

# %% [markdown]
# #### Exploring other datasets

# %% [markdown]
# Here is the attendance file to open up and find info on

# %%
df_a = pd.read_excel('attendance.xls', encoding = "iso-8859-1", header = 1)

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 17 columns):
# Unnamed: 0                                                                57 non-null object
# Total elementary, secondary, and combined elementary/secondary schools    54 non-null object
# Unnamed: 2                                                                52 non-null float64
# Unnamed: 3                                                                54 non-null object
# Unnamed: 4                                                                52 non-null float64
# Unnamed: 5                                                                54 non-null object
# Unnamed: 6                                                                52 non-null float64
# Unnamed: 7                                                                54 non-null object
# Unnamed: 8                                                                52 non-null float64
# ...

# %%
df_a.head(7)
# Out:
#                   Unnamed: 0  \
# 0                        NaN
# 1                          1
# 2     United States ........
# 3  Alabama .................
# 4  Alaska ..................
# 5  Arizona .................
# 6  Arkansas ................
#
#   Total elementary, secondary, and combined elementary/secondary schools  \
# 0                       ADA as percent of enrollment
# 1                                                  2
# 2                                             93.079
# 3                                            93.8124
# 4                                            89.9176
# 5                                             89.037
# 6                                            91.8271
#
#    Unnamed: 2                   Unnamed: 3  Unnamed: 4  \
# 0         NaN  Average hours in school day         NaN
# 1         NaN                            3         NaN
# 2    0.218555                       6.6447    0.017650
# ...

# %% [markdown]
# It's a good idea to also rename the titles of every column if they are unnamed, incorrect, or you just want to edit them.

# %%
new_labels = ['Total elementary, secondary and combined schools', 'ADA as a percent of enrollment', 'Average hours in a school day', 'average hours in a school year', 'Average hours in school year',  ]

# %%
# Here, I am printing the columns from my file.
print(df_a.columns.values)
# Out:
# ['Unnamed: 0'
#  'Total elementary, secondary, and combined elementary/secondary schools'
#  'Unnamed: 2' 'Unnamed: 3' 'Unnamed: 4' 'Unnamed: 5' 'Unnamed: 6'
#  'Unnamed: 7' 'Unnamed: 8' 'Elementary schools' 'Unnamed: 10'
#  'Unnamed: 11' 'Unnamed: 12' 'Secondary schools' 'Unnamed: 14'
#  'Unnamed: 15' 'Unnamed: 16']

# %% [markdown]
# Now I want to deal with the sales file

# %%
# Now here is the sales file. I'm going to repeat the steps from above

df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 46 columns):
# Unnamed: 0                5000 non-null int64
# event_id                  5000 non-null object
# primary_act_id            5000 non-null object
# secondary_act_id          5000 non-null object
# purch_party_lkup_id       5000 non-null object
# event_name                5000 non-null object
# primary_act_name          5000 non-null object
# secondary_act_name        1586 non-null object
# major_cat_name            5000 non-null object
# minor_cat_name            5000 non-null object
# la_event_type_cat         5000 non-null object
# event_disp_name           5000 non-null object
# ticket_text               5000 non-null object
# tickets_purchased_qty     5000 non-null int64
# trans_face_val_amt        5000 non-null float64
# delivery_type_cd          5000 non-null object
# event_date_time           5000 non-null object
# event_dt                  5000 non-null object
# ...

# %%
# The above is messy so I'm going to create a list of the columns
print(df_s.columns.values)
# Out:
# ['Unnamed: 0' 'event_id' 'primary_act_id' 'secondary_act_id'
#  'purch_party_lkup_id' 'event_name' 'primary_act_name'
#  'secondary_act_name' 'major_cat_name' 'minor_cat_name'
#  'la_event_type_cat' 'event_disp_name' 'ticket_text'
#  'tickets_purchased_qty' 'trans_face_val_amt' 'delivery_type_cd'
#  'event_date_time' 'event_dt' 'presale_dt' 'onsale_dt'
#  'sales_ord_create_dttm' 'sales_ord_tran_dt' 'print_dt' 'timezn_nm'
#  'venue_city' 'venue_state' 'venue_postal_cd_sgmt_1' 'sales_platform_cd'
#  'print_flg' 'la_valid_tkt_event_flg' 'fin_mkt_nm'
#  'web_session_cookie_val' 'gndr_cd' 'age_yr' 'income_amt' 'edu_val'
#  'edu_1st_indv_val' 'edu_2nd_indv_val' 'adults_in_hh_num' 'married_ind'
#  'child_present_ind' 'home_owner_ind' 'occpn_val' 'occpn_1st_val'
#  'occpn_2nd_val' 'dist_to_ven']

# %% [markdown]
# # Dataset preparation 1

# %% [markdown]
# #### Boing Boing Data Cleaning

# %% [markdown]
# From looking at the datasets, I've decided to work on the Boing boing candy data and the sales data. I have decided this because the atenndance data got messy and I was not able to organize the file correcty.

# %%
# Here's the Boing Boing data, ready to open

df_b = pd.read_excel('BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx', encoding = "iso-8859-1")

# %%
# Now here is how the headers of this file look like
df_b = pd.read_excel("BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx")
df_b.head(0)
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# As you can see, the second column is a little hard to understand due to the wording. I'm going to fix the column and look for any others that should be worded better.

# %%
# I see that there is a final column that says "ignore" so we'll go ahead and delete that.
df_b.drop(' [York Peppermint Patties] Ignore', axis=1, inplace=True)

# And we'll print our new data:
df_b
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# 5    2016-10-24 05:16:43.126
# 6    2016-10-24 05:16:50.572
# 7    2016-10-24 05:16:55.324
# 8    2016-10-24 05:17:49.292
# 9    2016-10-24 05:18:51.021
# 10   2016-10-24 05:20:21.125
# 11   2016-10-24 05:21:19.858
# 12   2016-10-24 05:21:27.708
# 13   2016-10-24 05:22:12.699
# 14   2016-10-24 05:22:30.678
# 15   2016-10-24 05:24:08.316
# 16   2016-10-24 05:24:11.446
# 17   2016-10-24 05:26:18.333
# 18   2016-10-24 05:26:35.167
# 19   2016-10-24 05:27:00.491
# 20   2016-10-24 05:30:39.763
# 21   2016-10-24 05:31:48.862
# 22   2016-10-24 05:33:18.915
# 23   2016-10-24 05:33:28.488
# 24   2016-10-24 05:34:36.438
# 25   2016-10-24 05:34:37.116
# 26   2016-10-24 05:34:40.001
# 27   2016-10-24 05:35:45.940
# 28   2016-10-24 05:36:13.156
# 29   2016-10-24 05:36:44.146
# ...                      ...
# ...

# %%
# Now that we have deleted a coumn, we will rename the second one to make everything look neater
df_b.rename(columns={'Are you going actually going trick or treating yourself?':'Are you going trick or treating?'}, inplace=True)
# Now here's the edited file
df_b
# Out:
#                    Timestamp Are you going trick or treating?  \
# 0    2016-10-24 05:09:23.033                               No
# 1    2016-10-24 05:09:54.798                               No
# 2    2016-10-24 05:13:06.734                               No
# 3    2016-10-24 05:14:17.192                               No
# 4    2016-10-24 05:14:24.625                              Yes
# 5    2016-10-24 05:16:43.126                               No
# 6    2016-10-24 05:16:50.572                              Yes
# 7    2016-10-24 05:16:55.324                               No
# 8    2016-10-24 05:17:49.292                              Yes
# 9    2016-10-24 05:18:51.021                               No
# 10   2016-10-24 05:20:21.125                               No
# 11   2016-10-24 05:21:19.858                               No
# 12   2016-10-24 05:21:27.708                               No
# 13   2016-10-24 05:22:12.699                              Yes
# ...

# %% [markdown]
# # Dataset preparation 2

# %% [markdown]
# Now we're going to perform some cleaning on the sales file

# %%
# Open the file
df_s = pd.read_csv('sales.csv', encoding = "iso-8859-1")

# %%
# Now here is how the headers of this file look like
df_s = pd.read_csv('sales.csv', encoding = "iso-8859-1")
df_s.head(8)
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
# 5           6  4f10fd8b9f550352bd56  ac4b847b3fde66f2117e
# 6           7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 7           8  593b910d17913d7101cb  91c03a34b562436efa3c
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
# 5  63814f3d63317f1b56c4  3b3a628f83135acd0676
# 6  b85143bf51323b72e53c  14af02b72584fa823f85
# 7  b85143bf51323b72e53c  c7878d51bb2d62d4705c
#
# ...

# %%
# I'm a little scared by how messy the data looks so I'm going to look a little closer at this file

df_s.describe()
# Out:
#         Unnamed: 0  tickets_purchased_qty  trans_face_val_amt      age_yr  \
# count  5000.000000             5000.00000         5000.000000  168.000000
# mean   2500.500000                1.63900           77.077446   44.369048
# std    1443.520003                1.11361          123.864788   16.531067
# min       1.000000                1.00000            1.000000   18.000000
# 25%    1250.750000                1.00000           20.000000   30.000000
# 50%    2500.500000                1.00000           30.000000   44.000000
# 75%    3750.250000                2.00000           85.000000   56.000000
# max    5000.000000                8.00000         1520.880000   94.000000
#
#           income_amt  adults_in_hh_num  married_ind  child_present_ind  \
# count     154.000000        176.000000   157.000000         130.000000
# mean    86396.103896          2.579545     0.668790           0.561538
# std     58895.045547          1.490707     0.472155           0.498118
# ...

# %%
# It defienetely looks like there is some valuable info, but the rows don't show much besides NaNs
# I'm going to drop rows that include NaN values to make this look neater

df_s.dropna()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, event_id, primary_act_id, secondary_act_id, purch_party_lkup_id, event_name, primary_act_name, secondary_act_name, major_cat_name, minor_cat_name, la_event_type_cat, event_disp_name, ticket_text, tickets_purchased_qty, trans_face_val_amt, delivery_type_cd, event_date_time, event_dt, presale_dt, onsale_dt, sales_ord_create_dttm, sales_ord_tran_dt, print_dt, timezn_nm, venue_city, venue_state, venue_postal_cd_sgmt_1, sales_platform_cd, print_flg, la_valid_tkt_event_flg, fin_mkt_nm, web_session_cookie_val, gndr_cd, age_yr, income_amt, edu_val, edu_1st_indv_val, edu_2nd_indv_val, adults_in_hh_num, married_ind, child_present_ind, home_owner_ind, occpn_val, occpn_1st_val, occpn_2nd_val]
# Index: []
#
# [0 rows x 45 columns]

# %%
# I'm a little concerned since I have nothing to work with. I wasn't able to save number values.
# I'm going to attempt to change the name of one of the columns because the underscores don't look pretty, but first I'm going to copy an paste from the file list
list(df_s)
# Out:
# ['Unnamed: 0',
#  'event_id',
#  'primary_act_id',
#  'secondary_act_id',
#  'purch_party_lkup_id',
#  'event_name',
#  'primary_act_name',
#  'secondary_act_name',
#  'major_cat_name',
#  'minor_cat_name',
#  'la_event_type_cat',
#  'event_disp_name',
#  'ticket_text',
#  'tickets_purchased_qty',
#  'trans_face_val_amt',
#  'delivery_type_cd',
#  'event_date_time',
#  'event_dt',
#  'presale_dt',
#  'onsale_dt',
#  'sales_ord_create_dttm',
#  'sales_ord_tran_dt',
#  'print_dt',
#  'timezn_nm',
#  'venue_city',
#  'venue_state',
#  'venue_postal_cd_sgmt_1',
#  'sales_platform_cd',
#  'print_flg',
#  'la_valid_tkt_event_flg',
#  'fin_mkt_nm',
#  'web_session_cookie_val',
#  'gndr_cd',
#  'age_yr',
#  'income_amt',
#  'edu_val',
#  'edu_1st_indv_val',
#  'edu_2nd_indv_val',
#  'adults_in_hh_num',
#  'married_ind',
#  'child_present_ind',
#  'home_owner_ind',
#  'occpn_val',
#  'occpn_1st_val',
#  'occpn_2nd_val',
#  'dist_to_ven']

# %%
# Now I'll rename
df_s.rename(columns={'tickets_purchased_qty':'Tickets purchased'}, inplace=True)
df_s
# Out:
#       Unnamed: 0              event_id        primary_act_id  \
# 0              1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1              2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2              3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3              4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4              5  55b5f67e618557929f48  91c03a34b562436efa3c
# 5              6  4f10fd8b9f550352bd56  ac4b847b3fde66f2117e
# 6              7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 7              8  593b910d17913d7101cb  91c03a34b562436efa3c
# 8              9  0fb4e7152e09a40ffedd  0efaba7ce3f0d7466b42
# 9             10  93fce8094d89e0a94aac  f6425a3223e73ea6de5a
# 10            11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 11            12  6adcf8b2dc8a761b22b7  094156ef72361776c8ee
# 12            13  d3c8f5fb844690fb5af6  732d4f52a3ac2b7de8ef
# 13            14  5c7d36b783905ba488f4  34ad0e9254b8f7d1cbe0
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# Data cleaning was definetely interesting and I personally enjoy it as there is a lot of problem solving that goes into it. However, Data cleaning was stressful and it was very hard to get over some hurdles a couple of times. In some cases, I wasn't able to keep going but I did my best to analyze the data as best I could.
# Through this lab, I have a greater appreciattion for good data and the work that goes into making datasets nice and organized.

# %% [markdown]
# # Acknowledgements

# %% [markdown]
# I want to thank Ms. Sconyers for providing code. I would also like to thank Theo for his advice on how to make sure our files got read properly
